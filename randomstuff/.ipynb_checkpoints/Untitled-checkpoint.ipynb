# %%
ini = [[1,1]]
n =4
# while search:
for i in range(n):
    print(i)
    comb = set([])
    for el in ini:
        comb.update(set([el[0]+el[1], el[1]]))
    ini.append(list(comb))
    print(ini)
# Out:
# 0
# [[1, 1], [1, 2]]
# 1
# [[1, 1], [1, 2], [1, 2, 3]]
# 2
# [[1, 1], [1, 2], [1, 2, 3], [1, 2, 3]]
# 3
# [[1, 1], [1, 2], [1, 2, 3], [1, 2, 3], [1, 2, 3]]

# %%
def subset_sum(numbers, target, partial=[]):
    s = sum(partial)

    # check if the partial sum is equals to target
    if s == target: 
        print "sum(%s)=%s" % (partial, target)
    if s >= target:
        return  # if we reach the number why bother to continue

    for i in range(len(numbers)):
        n = numbers[i]
        remaining = numbers[i+1:]
        subset_sum(remaining, target, partial + [n]) 


if __name__ == "__main__":
    subset_sum([3,9,8,4,5,7,10],15)
# Out:
# sum([3, 8, 4])=15
# sum([3, 5, 7])=15
# sum([8, 7])=15
# sum([5, 10])=15

# %%
def answer(n, count=0):
    
    if count==0:
        partial = []
        steps = range(n,0, -1)
    s = sum(partial)

    # check if the partial sum is equals to target
    if s == n: 
        count +=1
    if s >= n:
        return  count# if we reach the number why bother to continue

    for i in range(len(steps)):
        n = steps[i]
        remaining = steps[i+1:]
        partial.append(n)
        answer(n, count=count) 


if __name__ == "__main__":
    answer(6)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-9-efe3e539de1c> in <module>()
#      20
#      21 if __name__ == "__main__":
# ---> 22     answer(6)
#
# <ipython-input-9-efe3e539de1c> in answer(n, count)
#      16         remaining = steps[i+1:]
#      17         partial.append(n)
# ---> 18         answer(n, count=count)
#      19
#      20
#
# <ipython-input-9-efe3e539de1c> in answer(n, count)
#      16         remaining = steps[i+1:]
#      17         partial.append(n)
# ---> 18         answer(n, count=count)
#      19
#      20
#
# <ipython-input-9-efe3e539de1c> in answer(n, count)
#      16         remaining = steps[i+1:]
#      17         partial.append(n)
# ---> 18         answer(n, count=count)
#      19
#      20
#
# <ipython-input-9-efe3e539de1c> in answer(n, count)
#      16         remaining = steps[i+1:]
#      17         partial.append(n)
# ...

# %%
range(6,0, -1)
# Out:
# [6, 5, 4, 3, 2, 1]

# %%
b
# Out:
# ['b', 'a']

# %%
M = "4"
F = "2"

pair = [int(M),int(F)]
print(pair)
cycles = 0
print(cycles)
while sum(pair)>2:
    pair = [max(pair)-min(pair), min(pair)]
    print(pair)
    cycles += 1
    print(cycles)
if min(pair)<1:
    cycles = "imposible"
str(cycles)
# Out:
# [4, 2]
# 0
# [2, 2]
# 1
# [0, 2]
# 2
# 'imposible'

# %%
for el in pair:
    print(int(el))
# Out:
# 4
# 7

# %%
10^50
# Out:
# 56

# %%
[10000000000, 7, 1428571432]
# Out:
# '4'

# %%
10000000000**1/7
# Out:
# 1428571428

# %%
a = [[] for i in xrange(3)]

# %%
ini = [[1,1]]
ini = comb[:]
for el in ini:
    comb.extend([[el[0], el[1]+el[0]], [el[0]+el[1], el[1]]])
# Out:
# [[], [], []]

# %%
s_chunk = 0
for i in range(0):
    s_chunk +=i
